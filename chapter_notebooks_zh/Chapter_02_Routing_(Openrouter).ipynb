# %%
import requests
import json
response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "Bearer <OPENROUTER_API_KEY>",
    "HTTP-Referer": "<YOUR_SITE_URL>", # 选修的。 openrouter.ai 排名的站点 URL。
    "X-Title": "<YOUR_SITE_NAME>", # 选修的。 openrouter.ai 排名的网站标题。
  },
  data=json.dumps({
    "model": "openai/gpt-4o", # 选修的
    "messages": [
      {
        "role": "user",
        "content": "What is the meaning of life?"
      }
    ]
  })
)
